# %%
import h5py
import matplotlib.pyplot as plt

filename = "../../data/images/ground_truth_test/ground_truth_test_000.hdf5"

with h5py.File(filename, "r") as f:
    print("Keys: %s" % f.keys())
    data = f["data"][:]
    print(data.shape, data.dtype)
    img = data[1]

# Display image
plt.imshow(img, cmap="gray")
plt.show()
# Out:
# Keys: <KeysViewHDF5 ['data']>
# (128, 362, 362) float32
